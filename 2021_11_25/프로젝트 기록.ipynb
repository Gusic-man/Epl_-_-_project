# %% [markdown]
# # 프로젝트 활동 기록 보고서

# %% [markdown]
# ## 주제
# - EPL 데이터 분석 및 시각화
#     - EPL이란 잉글랜드 프리미어 리그로 해외 축구리그에서 가장 흥행하고 잇는 리그.
#     - 본인은 축구를 굉장히 좋아하며 이번 프로젝트에 내가 좋아하는 것을 접목시키면 흥미로울 것이라 생각.
#     - 마침 파이썬에서 데이터 시각화의 중요성과 방법을 배웠고, 나도 내가 원하는 데이터를 내가 입맛대로 분석하고 싶은 욕심이 생겨 이 프로젝트를 실행.

# %% [markdown]
# ## 활동 기록

# %% [markdown]
# ### 2021/11/18~ 2021/11/20

# %% [markdown]
# - 주제 확정후 필요한 공부 학습
# - 데이터 분석을 위한 pandas 공부
# - 데이터 시각화를 위한 수업 시간에 배운 matploilib 복습 및 추가 학습

# %% [markdown]
# ### 2021/11/21

# %% [markdown]
# - 원하는 EPL 데이터 파일을 찾지못함
# - 직접 데이터를 얻기로 결심.
# - 웹 스크래핑 기술을 배우기로 함.
# - request와 bs4(Beautifulsoup4)을 학습
# - 후드스코어 및 언더 스탯 웹 사이트 데이터 분석을 목표
# - 데이터 수집을 시도했으나 실패하여 이유를 분석
# - 후드스코어 및 언더 스탯에 있는 데이터들은 동적 웹 사이트라 bs4로는 불가능함.

# %% [markdown]
# ### 2021/11/22

# %% [markdown]
# - 동적 웹 사이트를 스크래핑 허가 위해서는 Selenium 을 써야되는 것을 알게 됨.
# - selenium 학습
# - 데이터 방법 터득.
# - 언더스탯에서 2014년도 부터 2020년도 까지의 EPL 데이터를 습득.

# %% [markdown]
# ### 2021/11/23
#
# - 세부주제를 뛰어난 활약을 펼치는 손흥민 선수를 대상으로 하기로 결정.
# - 손흥민 선수가 EPL로 이적을 온 2015년도 부터 2020년 데이터를 받아와 분석
# - 처음엔 골 기록으로 그래프를 그려 년도별 성장세를 시각화하여 ppt를 통해 디자인

# %%
from IPython.display import Image

# %% [markdown]
# #### 첫 결과물

# %%
Image("손흥민_데이터시각화_1.png")

# %% [markdown]
# ### 2021/11/24

# %% [markdown]
# - 우선 위의 기록에 어시스트까지 더하여 총 공격포인트로 분석을 하는 것으로 수정하였다.

# %%
Image("손흥민 데이터분석2.png")

# %% [markdown]
# - 커리어 하이를 기록한 시즌인 2020/2021 시즌에 손흥민 선수가 얼마나 좋은 공격수 인지 분석해보았다.

# %%
Image("손흥민 데이터분석_3.png")

# %%
Image("손흥민 데이터분석_4.png")

# %% [markdown]
# - 굉장히 효율도 좋고 기록도 좋은 스트라이커였다는 것이 증명 되었다.
# - 다른 세부기록에서도 좋은 기록을 가졌기 때문에 커리어 하이인 시즌이 되었다고 생각된다.
# - 그래서 언더스탯 사이트말고 세부기록 위주인 후스스코어드에서 데이터를 새롭게 수집하려고 한다.

# %% [markdown]
# ### 2021/11/25

# %% [markdown]
# - 오늘은 프로젝트를 마무리 하려는 날이다.

# %% [markdown]
# - 첫번째로 손흥민 선수의 2020/2021 시즌 지표를 집중적으로 분석 및 시각화하기 위해 후스스코어에서 데이러를 스크래핑하였다,  .

# %% [markdown]
# - 두번째로는 수집한 데이터를 바탕으로 분석 및 시각화를 진행하였다.

# %%
Image("손흥민 데이터분석_5.png")

# %% [markdown]
# - 마지막 분석 및 시각화로는 원형 그래프를 그려 손흥민의 평균 기록과 나머지 상위 선수들의 평균기록을 비교해보았다

# %%
Image("손흥민 데이터분석_6.png")

# %% [markdown]
# ### 후기

# %% [markdown]
# - 약 일주일 동안 정말 시간을 갈아 넣어 이 프로젝트에 몰두하였다.
# - 무작정 주제를 정했다가. 따로 공부해야 할것이 너무 많아 너무 막막했다.
# - 그래도 요번학기 부터 전과를 한 나에게 첫 프로젝트라 최대한 노력을 해보기로 하였다.
# - 다행히 내가 좋아하는 분야를 접목한덕에 나름 즐기면서 한것같다.
# - 혼자 진행하고 처음이다보니 완성도가 약간 아쉬운것같다.
# - 일단은 여기서 마무리를 해야할것같다. 다른 프로젝트도 있고, 시험공부도 있으니..
# - 정말 좋고 유익학 프로젝트였던거 같다.
